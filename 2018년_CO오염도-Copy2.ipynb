# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

co_01= pd.read_csv('C:\\신현호\\코딩스터디\\18년도_1월_CO오염도_최종본.csv', encoding = 'utf-8')

co_01 = co_01.drop(columns = ['측정소명'])
#co_01 = co_01.reset_index()
#co_01 = co_01.drop(columns = ['index'])
co_01
# Out:
#   시.도 시군구  지점  오염도 월평균(ppm)
# 0  서울  서울  서울          0.64
# 1  경기  경기  경기          0.67
# 2  인천  인천  인천          0.70
# 3  대구  대구  대구          0.58
# 4  제주  제주  제주          0.28

# %%
#히스토그램
import matplotlib.font_manager as fm

list_01 = []
list_02 = []
data_01 = co_01['시군구'].values.reshape(1,-1)
data_02 = co_01['오염도 월평균(ppm)'].values.reshape(1,-1)

data_01 = data_01.tolist()
data_02 = data_02.tolist()
for i in data_01:
    list_01.append(i)
for j in data_02:
    list_02.append(j)

#sum(my_list, [])
list_01 = sum(list_01,[])
list_02 = sum(list_02,[])

# font_path = r'C:\\Users\\hhshi\\Downloads\\NanumFontSetup_TTF_ALL\\NanumBarunGothic.ttf'
# fontprop = fm.FontProperties(fname=font_path, size=10)

plt.rc('font', family='NanumGothic')
#print(plt.rcParams['font.family'])

plt.title('2018년도 1월 CO 오염도')
#plt.rcParams["figure.figsize"] = (10, 5)
plt.bar(list_01, list_02, color = 'b',width = 0.4)
plt.xlabel('시군구')
plt.ylabel('CO 오염도')
plt.xticks(rotation='vertical')
plt.legend(labels= ['오염도 수치'], loc='best', fontsize = 10)
plt.show()

# %%
co_02= pd.read_csv('C:\\신현호\\코딩스터디\\18년도_2월_CO오염도_최종본.csv', encoding = 'utf-8')

co_02 = co_02.drop(columns = ['측정소명'])
#co_01 = co_01.reset_index()
#co_01 = co_01.drop(columns = ['index'])
co_02
# Out:
#   시.도 시군구  지점  오염도 월평균(ppm)
# 0  서울  서울  서울          0.62
# 1  경기  경기  경기          0.58
# 2  인천  인천  인천          0.64
# 3  대구  대구  대구          0.54
# 4  제주  제주  제주          0.35

# %%
#히스토그램
import matplotlib.font_manager as fm

list_01_02 = []
list_02_02 = []
data_01_02 = co_02['시군구'].values.reshape(1,-1)
data_02_02 = co_02['오염도 월평균(ppm)'].values.reshape(1,-1)

data_01_02 = data_01_02.tolist()
data_02_02 = data_02_02.tolist()
for i in data_01_02:
    list_01_02.append(i)
for j in data_02_02:
    list_02_02.append(j)

#sum(my_list, [])
list_01_02 = sum(list_01_02,[])
list_02_02 = sum(list_02_02,[])

# font_path = r'C:\\Users\\hhshi\\Downloads\\NanumFontSetup_TTF_ALL\\NanumBarunGothic.ttf'
# fontprop = fm.FontProperties(fname=font_path, size=10)

plt.rc('font', family='NanumGothic')
#print(plt.rcParams['font.family'])

plt.title('2018년도 2월 CO 오염도')
plt.bar(list_01_02, list_02_02, color = 'b',width = 0.4)
plt.xlabel('시군구')
plt.ylabel('CO 오염도')
plt.xticks(rotation='vertical')
plt.legend(labels= ['오염도 수치'], loc='best', fontsize = 10)
plt.show()

# %%
co_03= pd.read_csv('C:\\신현호\\코딩스터디\\18년도_3월_CO오염도_최종본.csv', encoding = 'utf-8')

co_03 = co_03.drop(columns = ['측정소명'])
#co_01 = co_01.reset_index()
#co_01 = co_01.drop(columns = ['index'])
co_03
# Out:
#   시.도 시군구  지점  오염도 월평균(ppm)
# 0  서울  서울  서울          0.55
# 1  경기  경기  경기          0.53
# 2  인천  인천  인천          0.55
# 3  대구  대구  대구          0.25
# 4  제주  제주  제주          0.40

# %%
#히스토그램
import matplotlib.font_manager as fm

list_01_03 = []
list_02_03 = []
data_01_03 = co_03['시군구'].values.reshape(1,-1)
data_02_03 = co_03['오염도 월평균(ppm)'].values.reshape(1,-1)

data_01_03 = data_01_03.tolist()
data_02_03 = data_02_03.tolist()
for i in data_01_03:
    list_01_03.append(i)
for j in data_02_03:
    list_02_03.append(j)

#sum(my_list, [])
list_01_03 = sum(list_01_03,[])
list_02_03 = sum(list_02_03,[])

# font_path = r'C:\\Users\\hhshi\\Downloads\\NanumFontSetup_TTF_ALL\\NanumBarunGothic.ttf'
# fontprop = fm.FontProperties(fname=font_path, size=10)

plt.rc('font', family='NanumGothic')
#print(plt.rcParams['font.family'])

plt.title('2018년도 3월 CO 오염도')
plt.bar(list_01_03, list_02_03, color = 'b',width = 0.4)
plt.xlabel('시군구')
plt.ylabel('CO 오염도')
plt.xticks(rotation='vertical')
plt.legend(labels= ['오염도 수치'], loc='best', fontsize = 10)
plt.show()

# %%
co_04= pd.read_csv('C:\\신현호\\코딩스터디\\18년도_4월_CO오염도_최종본.csv', encoding = 'utf-8')

co_04 = co_04.drop(columns = ['측정소명'])
#co_01 = co_01.reset_index()
#co_01 = co_01.drop(columns = ['index'])
co_04
# Out:
#   시.도 시군구  지점  월평균\n(ppm)
# 0  서울  서울  서울        0.48
# 1  경기  경기  경기        0.41
# 2  인천  인천  인천        0.50
# 3  대구  대구  대구        0.38
# 4  제주  제주  제주        0.28

# %%
#히스토그램
import matplotlib.font_manager as fm

list_01_04 = []
list_02_04 = []
data_01_04 = co_04['시군구'].values.reshape(1,-1)
data_02_04 = co_04['월평균\n(ppm)'].values.reshape(1,-1)

data_01_04 = data_01_04.tolist()
data_02_04 = data_02_04.tolist()
for i in data_01_04:
    list_01_04.append(i)
for j in data_02_04:
    list_02_04.append(j)

#sum(my_list, [])
list_01_04 = sum(list_01_04,[])
list_02_04 = sum(list_02_04,[])

# font_path = r'C:\\Users\\hhshi\\Downloads\\NanumFontSetup_TTF_ALL\\NanumBarunGothic.ttf'
# fontprop = fm.FontProperties(fname=font_path, size=10)

plt.rc('font', family='NanumGothic')
#print(plt.rcParams['font.family'])

plt.title('2018년도 4월 CO 오염도')
plt.bar(list_01_04, list_02_04, color = 'b',width = 0.4)
plt.xlabel('시군구')
plt.ylabel('CO 오염도')
plt.xticks(rotation='vertical')
plt.legend(labels= ['오염도 수치'], loc='best', fontsize = 10)
plt.show()

# %%
co_05= pd.read_csv('C:\\신현호\\코딩스터디\\18년도_5월_CO오염도_최종본.csv', encoding = 'utf-8')

co_05 = co_05.drop(columns = ['측정소명'])
#co_01 = co_01.reset_index()
#co_01 = co_01.drop(columns = ['index'])
co_05
# Out:
#   시.도 시군구  지점  월평균\n(ppm)
# 0  서울  서울  서울        0.44
# 1  경기  경기  경기        0.39
# 2  인천  인천  인천        0.46
# 3  대구  대구  대구        0.34
# 4  제주  제주  제주        0.23

# %%
#히스토그램
import matplotlib.font_manager as fm

list_01_05 = []
list_02_05 = []
data_01_05 = co_05['시군구'].values.reshape(1,-1)
data_02_05 = co_05['월평균\n(ppm)'].values.reshape(1,-1)

data_01_05 = data_01_05.tolist()
data_02_05 = data_02_05.tolist()
for i in data_01_05:
    list_01_05.append(i)
for j in data_02_05:
    list_02_05.append(j)

#sum(my_list, [])
list_01_05 = sum(list_01_05,[])
list_02_05 = sum(list_02_05,[])

# font_path = r'C:\\Users\\hhshi\\Downloads\\NanumFontSetup_TTF_ALL\\NanumBarunGothic.ttf'
# fontprop = fm.FontProperties(fname=font_path, size=10)

plt.rc('font', family='NanumGothic')
#print(plt.rcParams['font.family'])

plt.title('2018년도 5월 CO 오염도')
plt.bar(list_01_05, list_02_05, color = 'b',width = 0.4)
plt.xlabel('시군구')
plt.ylabel('CO 오염도')
plt.xticks(rotation='vertical')
plt.legend(labels= ['오염도 수치'], loc='best', fontsize = 10)
plt.show()

# %%
co_06= pd.read_csv('C:\\신현호\\코딩스터디\\18년도_6월_CO오염도_최종본.csv', encoding = 'utf-8')

co_06 = co_06.drop(columns = ['측정소명'])
#co_01 = co_01.reset_index()
#co_01 = co_01.drop(columns = ['index'])
co_06
# Out:
#   시.도 시군구  지점  월평균\n(ppm)
# 0  서울  서울  서울        0.45
# 1  경기  경기  경기        0.37
# 2  인천  인천  인천        0.44
# 3  대구  대구  대구        0.32
# 4  제주  제주  제주        0.18

# %%
#히스토그램
import matplotlib.font_manager as fm

list_01_06 = []
list_02_06 = []
data_01_06 = co_06['시군구'].values.reshape(1,-1)
data_02_06 = co_06['월평균\n(ppm)'].values.reshape(1,-1)

data_01_06 = data_01_06.tolist()
data_02_06 = data_02_06.tolist()
for i in data_01_06:
    list_01_06.append(i)
for j in data_02_06:
    list_02_06.append(j)

#sum(my_list, [])
list_01_06 = sum(list_01_06,[])
list_02_06 = sum(list_02_06,[])

# font_path = r'C:\\Users\\hhshi\\Downloads\\NanumFontSetup_TTF_ALL\\NanumBarunGothic.ttf'
# fontprop = fm.FontProperties(fname=font_path, size=10)

plt.rc('font', family='NanumGothic')
#print(plt.rcParams['font.family'])

plt.title('2018년도 6월 CO 오염도')
plt.bar(list_01_06, list_02_06, color = 'b',width = 0.4)
plt.xlabel('시군구')
plt.ylabel('CO 오염도')
plt.xticks(rotation='vertical')
plt.legend(labels= ['오염도 수치'], loc='best', fontsize = 10)
plt.show()

# %%
co_07= pd.read_csv('C:\\신현호\\코딩스터디\\18년도_7월_CO오염도_최종본.csv', encoding = 'utf-8')

co_07 = co_07.drop(columns = ['측정소명'])
#co_01 = co_01.reset_index()
#co_01 = co_01.drop(columns = ['index'])
co_07
# Out:
#   시.도 시군구  지점  월평균\n(ppm)
# 0  서울  서울  서울        0.37
# 1  경기  경기  경기        0.32
# 2  인천  인천  인천        0.39
# 3  대구  대구  대구        0.29
# 4  제주  제주  제주        0.15

# %%
#히스토그램
import matplotlib.font_manager as fm

list_01_07 = []
list_02_07 = []
data_01_07 = co_07['시군구'].values.reshape(1,-1)
data_02_07 = co_07['월평균\n(ppm)'].values.reshape(1,-1)

data_01_07 = data_01_07.tolist()
data_02_07 = data_02_07.tolist()
for i in data_01_07:
    list_01_07.append(i)
for j in data_02_07:
    list_02_07.append(j)

#sum(my_list, [])
list_01_07 = sum(list_01_07,[])
list_02_07 = sum(list_02_07,[])

# font_path = r'C:\\Users\\hhshi\\Downloads\\NanumFontSetup_TTF_ALL\\NanumBarunGothic.ttf'
# fontprop = fm.FontProperties(fname=font_path, size=10)

plt.rc('font', family='NanumGothic')
#print(plt.rcParams['font.family'])

plt.title('2018년도 7월 CO 오염도')
plt.bar(list_01_07, list_02_07, color = 'b',width = 0.4)
plt.xlabel('시군구')
plt.ylabel('CO 오염도')
plt.xticks(rotation='vertical')
plt.legend(labels= ['오염도 수치'], loc='best', fontsize = 10)
plt.show()

# %%
co_08= pd.read_csv('C:\\신현호\\코딩스터디\\18년도_8월_CO오염도_최종본.csv', encoding = 'utf-8')

co_08 = co_08.drop(columns = ['측정소명'])
#co_01 = co_01.reset_index()
#co_01 = co_01.drop(columns = ['index'])
co_08
# Out:
#   시.도 시군구  지점  월평균\n(ppm)
# 0  서울  서울  서울        0.36
# 1  경기  경기  경기        0.34
# 2  인천  인천  인천        0.38
# 3  대구  대구  대구        0.31
# 4  제주  제주  제주        0.15

# %%
#히스토그램
import matplotlib.font_manager as fm

list_01_08 = []
list_02_08 = []
data_01_08 = co_08['시군구'].values.reshape(1,-1)
data_02_08 = co_08['월평균\n(ppm)'].values.reshape(1,-1)

data_01_08 = data_01_08.tolist()
data_02_08 = data_02_08.tolist()
for i in data_01_08:
    list_01_08.append(i)
for j in data_02_08:
    list_02_08.append(j)

#sum(my_list, [])
list_01_08 = sum(list_01_08,[])
list_02_08 = sum(list_02_08,[])

# font_path = r'C:\\Users\\hhshi\\Downloads\\NanumFontSetup_TTF_ALL\\NanumBarunGothic.ttf'
# fontprop = fm.FontProperties(fname=font_path, size=10)

plt.rc('font', family='NanumGothic')
#print(plt.rcParams['font.family'])

plt.title('2018년도 8월 CO 오염도')
plt.bar(list_01_08, list_02_08, color = 'b',width = 0.4)
plt.xlabel('시군구')
plt.ylabel('CO 오염도')
plt.xticks(rotation='vertical')
plt.legend(labels= ['오염도 수치'], loc='best', fontsize = 10)
plt.show()

# %%
co_09= pd.read_csv('C:\\신현호\\코딩스터디\\18년도_9월_CO오염도_최종본.csv', encoding = 'utf-8')

co_09 = co_09.drop(columns = ['측정소명'])
#co_01 = co_01.reset_index()
#co_01 = co_01.drop(columns = ['index'])
co_09
# Out:
#   시.도 시군구  지점  월평균\n(ppm)
# 0  서울  서울  서울        0.38
# 1  경기  경기  경기        0.36
# 2  인천  인천  인천        0.43
# 3  대구  대구  대구        0.32
# 4  제주  제주  제주        0.15

# %%
#히스토그램
import matplotlib.font_manager as fm

list_01_09 = []
list_02_09 = []
data_01_09 = co_09['시군구'].values.reshape(1,-1)
data_02_09 = co_09['월평균\n(ppm)'].values.reshape(1,-1)

data_01_09 = data_01_09.tolist()
data_02_09 = data_02_09.tolist()
for i in data_01_09:
    list_01_09.append(i)
for j in data_02_09:
    list_02_09.append(j)

#sum(my_list, [])
list_01_09 = sum(list_01_09,[])
list_02_09 = sum(list_02_09,[])

# font_path = r'C:\\Users\\hhshi\\Downloads\\NanumFontSetup_TTF_ALL\\NanumBarunGothic.ttf'
# fontprop = fm.FontProperties(fname=font_path, size=10)

plt.rc('font', family='NanumGothic')
#print(plt.rcParams['font.family'])

plt.title('2018년도 9월 CO 오염도')
plt.bar(list_01_09, list_02_09, color = 'b',width = 0.4)
plt.xlabel('시군구')
plt.ylabel('CO 오염도')
plt.xticks(rotation='vertical')
plt.legend(labels= ['오염도 수치'], loc='best', fontsize = 10)
plt.show()

# %%
co_10= pd.read_csv('C:\\신현호\\코딩스터디\\18년도_10월_CO오염도_최종본.csv', encoding = 'utf-8')

co_10 = co_10.drop(columns = ['측정소명'])
#co_01 = co_01.reset_index()
#co_01 = co_01.drop(columns = ['index'])
co_10
# Out:
#   시.도 시군구  월평균\n(ppm)
# 0  서울  서울        0.47
# 1  경기  경기        0.43
# 2  인천  인천        0.50
# 3  대구  대구        0.40
# 4  제주  제주        0.23

# %%
#히스토그램
import matplotlib.font_manager as fm

list_01_10 = []
list_02_10 = []
data_01_10 = co_10['시군구'].values.reshape(1,-1)
data_02_10 = co_10['월평균\n(ppm)'].values.reshape(1,-1)

data_01_10 = data_01_10.tolist()
data_02_10 = data_02_10.tolist()
for i in data_01_10:
    list_01_10.append(i)
for j in data_02_10:
    list_02_10.append(j)

#sum(my_list, [])
list_01_10 = sum(list_01_10,[])
list_02_10 = sum(list_02_10,[])

# font_path = r'C:\\Users\\hhshi\\Downloads\\NanumFontSetup_TTF_ALL\\NanumBarunGothic.ttf'
# fontprop = fm.FontProperties(fname=font_path, size=10)

plt.rc('font', family='NanumGothic')
#print(plt.rcParams['font.family'])

plt.title('2018년도 10월 CO 오염도')
plt.bar(list_01_10, list_02_10, color = 'b',width = 0.4)
plt.xlabel('시군구')
plt.ylabel('CO 오염도')
plt.xticks(rotation='vertical')
plt.legend(labels= ['오염도 수치'], loc='best', fontsize = 10)
plt.show()

# %%
co_11= pd.read_csv('C:\\신현호\\코딩스터디\\18년도_11월_CO오염도_최종본.csv', encoding = 'utf-8')

co_11 = co_11.drop(columns = ['측정소명'])
#co_01 = co_01.reset_index()
#co_01 = co_01.drop(columns = ['index'])
co_11
# Out:
#   시.도 시군구  월평균\n(ppm)
# 0  서울  서울        0.66
# 1  경기  경기        0.61
# 2  인천  인천        0.65
# 3  대구  대구        0.58
# 4  제주  제주        0.25

# %%
#히스토그램
import matplotlib.font_manager as fm

list_01_11 = []
list_02_11 = []
data_01_11 = co_11['시군구'].values.reshape(1,-1)
data_02_11 = co_11['월평균\n(ppm)'].values.reshape(1,-1)

data_01_11 = data_01_11.tolist()
data_02_11 = data_02_11.tolist()
for i in data_01_11:
    list_01_11.append(i)
for j in data_02_11:
    list_02_11.append(j)

#sum(my_list, [])
list_01_11 = sum(list_01_11,[])
list_02_11 = sum(list_02_11,[])

# font_path = r'C:\\Users\\hhshi\\Downloads\\NanumFontSetup_TTF_ALL\\NanumBarunGothic.ttf'
# fontprop = fm.FontProperties(fname=font_path, size=10)

plt.rc('font', family='NanumGothic')
#print(plt.rcParams['font.family'])

plt.title('2018년도 11월 CO 오염도')
plt.bar(list_01_11, list_02_11, color = 'b',width = 0.4)
plt.xlabel('시군구')
plt.ylabel('CO 오염도')
plt.xticks(rotation='vertical')
plt.legend(labels= ['오염도 수치'], loc='best', fontsize = 10)
plt.show()

# %%
co_12= pd.read_csv('C:\\신현호\\코딩스터디\\18년도_12월_CO오염도_최종본.csv', encoding = 'utf-8')

co_12 = co_12.drop(columns = ['측정소명'])
#co_01 = co_01.reset_index()
#co_01 = co_01.drop(columns = ['index'])
co_12
# Out:
#   시.도 시군구  월평균\n(ppm)
# 0  서울  서울        0.65
# 1  경기  경기        0.61
# 2  인천  인천        0.64
# 3  대구  대구        0.61
# 4  제주  제주        0.25

# %%
#히스토그램
import matplotlib.font_manager as fm

list_01_12 = []
list_02_12 = []
data_01_12 = co_12['시군구'].values.reshape(1,-1)
data_02_12 = co_12['월평균\n(ppm)'].values.reshape(1,-1)

data_01_12 = data_01_12.tolist()
data_02_12 = data_02_12.tolist()
for i in data_01_12:
    list_01_12.append(i)
for j in data_02_12:
    list_02_12.append(j)

#sum(my_list, [])
list_01_12 = sum(list_01_12,[])
list_02_12 = sum(list_02_12,[])

# font_path = r'C:\\Users\\hhshi\\Downloads\\NanumFontSetup_TTF_ALL\\NanumBarunGothic.ttf'
# fontprop = fm.FontProperties(fname=font_path, size=10)

plt.rc('font', family='NanumGothic')
#print(plt.rcParams['font.family'])

plt.title('2018년도 12월 CO 오염도')
plt.bar(list_01_12, list_02_12, color = 'b',width = 0.4)
plt.xlabel('시군구')
plt.ylabel('CO 오염도')
plt.xticks(rotation='vertical')
plt.legend(labels= ['오염도 수치'], loc='best', fontsize = 10)
plt.show()

# %%
hi = pd.read_csv('C:\\신현호\\코딩스터디\\일반자동차_2018년_1월\\2018년_1월_일반자동차.csv', encoding = 'utf-8')
hi
# Out:
#       지역           서울           대구           인천           경기         제주
# 0     총계   3,118,469    1,159,779    1,518,259    5,410,671    504,384
# 1  전기차 수         1201          638          251          833      3,331
# 2  일반차 수    3,117,268    1,159,141    1,518,008    5,409,838    501,053
